# %%
# Import the library file
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the data set
ca= pd.read_excel('compactiv.xlsx')

# %%
# To view the top 5 record using head function of the dataset
ca.head()
# Out:
#    lread  lwrite  scall  sread  swrite  fork  exec    rchar    wchar  pgout  \
# 0      1       0   2147     79      68   0.2   0.2  40671.0  53995.0    0.0
# 1      0       0    170     18      21   0.2   0.2    448.0   8385.0    0.0
# 2     15       3   2162    159     119   2.0   2.4      NaN  31950.0    0.0
# 3      0       0    160     12      16   0.2   0.2      NaN   8670.0    0.0
# 4      5       1    330     39      38   0.4   0.4      NaN  12185.0    0.0
#
#    ...  pgscan  atch  pgin  ppgin    pflt    vflt         runqsz  freemem  \
# 0  ...     0.0   0.0   1.6    2.6   16.00   26.40      CPU_Bound     4670
# 1  ...     0.0   0.0   0.0    0.0   15.63   16.83  Not_CPU_Bound     7278
# 2  ...     0.0   1.2   6.0    9.4  150.20  220.20  Not_CPU_Bound      702
# 3  ...     0.0   0.0   0.2    0.2   15.60   16.80  Not_CPU_Bound     7248
# 4  ...     0.0   0.0   1.0    1.2   37.80   47.60  Not_CPU_Bound      633
#
#   freeswap  usr
# 0  1730946   95
# 1  1869002   97
# ...

# %%
# To view the last 5 record using tail function of the dataset
ca.tail()
# Out:
#       lread  lwrite  scall  sread  swrite  fork  exec     rchar    wchar  \
# 8187     16      12   3009    360     244   1.6  5.81  405250.0  85282.0
# 8188      4       0   1596    170     146   2.4  1.80   89489.0  41764.0
# 8189     16       5   3116    289     190   0.6  0.60  325948.0  52640.0
# 8190     32      45   5180    254     179   1.2  1.20   62571.0  29505.0
# 8191      2       0    985     55      46   1.6  4.80  111111.0  22256.0
#
#       pgout  ...  pgscan  atch   pgin  ppgin    pflt    vflt         runqsz  \
# 8187   8.02  ...   55.11   0.6  35.87  47.90  139.28  270.74      CPU_Bound
# 8188   3.80  ...    0.20   0.8   3.80   4.40  122.40  212.60  Not_CPU_Bound
# 8189   0.40  ...    0.00   0.4  28.40  45.20   60.20  219.80  Not_CPU_Bound
# 8190   1.40  ...   18.04   0.4  23.05  24.25   93.19  202.81      CPU_Bound
# 8191   0.00  ...    0.00   0.2   3.40   6.20   91.80  110.00      CPU_Bound
#
#       freemem freeswap  usr
# 8187      387   986647   80
# ...

# %%
# To print number of rows and columns present in the dataset
print("no.of rows: ",ca.shape[0], "no.of columns:",ca.shape[1])
# Out:
# no.of rows:  8192 no.of columns: 22

# %%
# To view the shape of the dataset
ca.shape
# Out:
# (8192, 22)

# %%
# To view describe the dataset
ca.describe().T
# Out:
#            count          mean            std     min        25%        50%  \
# lread     8192.0  1.955969e+01      53.353799     0.0        2.0        7.0
# lwrite    8192.0  1.310620e+01      29.891726     0.0        0.0        1.0
# scall     8192.0  2.306318e+03    1633.617322   109.0     1012.0     2051.5
# sread     8192.0  2.104800e+02     198.980146     6.0       86.0      166.0
# swrite    8192.0  1.500582e+02     160.478980     7.0       63.0      117.0
# fork      8192.0  1.884554e+00       2.479493     0.0        0.4        0.8
# exec      8192.0  2.791998e+00       5.212456     0.0        0.2        1.2
# rchar     8088.0  1.973857e+05  239837.493526   278.0    34091.5   125473.5
# wchar     8177.0  9.590299e+04  140841.707911  1498.0    22916.0    46619.0
# pgout     8192.0  2.285317e+00       5.307038     0.0        0.0        0.0
# ppgout    8192.0  5.977229e+00      15.214590     0.0        0.0        0.0
# ...

# %%
# To view info of the dataset
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lread     8192 non-null   int64
#  1   lwrite    8192 non-null   int64
#  2   scall     8192 non-null   int64
#  3   sread     8192 non-null   int64
#  4   swrite    8192 non-null   int64
#  5   fork      8192 non-null   float64
#  6   exec      8192 non-null   float64
#  7   rchar     8088 non-null   float64
#  8   wchar     8177 non-null   float64
#  9   pgout     8192 non-null   float64
#  10  ppgout    8192 non-null   float64
#  11  pgfree    8192 non-null   float64
#  12  pgscan    8192 non-null   float64
#  13  atch      8192 non-null   float64
#  14  pgin      8192 non-null   float64
#  15  ppgin     8192 non-null   float64
#  16  pflt      8192 non-null   float64
#  17  vflt      8192 non-null   float64
#  18  runqsz    8192 non-null   object
#  19  freemem   8192 non-null   int64
# ...

# %%
# To Check for null values in the dataset
ca.isnull().sum()
# Out:
# lread         0
# lwrite        0
# scall         0
# sread         0
# swrite        0
# fork          0
# exec          0
# rchar       104
# wchar        15
# pgout         0
# ppgout        0
# pgfree        0
# pgscan        0
# atch          0
# pgin          0
# ppgin         0
# pflt          0
# vflt          0
# runqsz        0
# freemem       0
# freeswap      0
# usr           0
# dtype: int64

# %%
# To Check the dulipciate values in the dataset
ca.duplicated().sum()
# Out:
# 0

# %%
# To Check for duplicate values in the dataset

dups = ca.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

ca[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [lread, lwrite, scall, sread, swrite, fork, exec, rchar, wchar, pgout, ppgout, pgfree, pgscan, atch, pgin, ppgin, pflt, vflt, runqsz, freemem, freeswap, usr]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Insight:
#     * 1) Database administrator would be checking the size of the dataset using '.shape' which throw output for number of rows and number of columns and using '.info()' for checking the type of variables in the dataset.
#     * 2) There are 8192 number of rows and 22 columns in the dataset.
#     * 3) There are 8 in int64, 13 in float64 and 1 in object present in the dataset
#     * 4) No duplicate records is present in the dataset
#     * 5) Null value present in the dataset for rchar is having 104 rows & wchar is having 15 rows

# %%
# Replacing blank value with Median
median_1 = ca['wchar'].median()
ca['wchar'] = ca['wchar'].replace(np.nan,median_1)
ca['wchar'].isnull().sum()
median_2 = ca['rchar'].median()
ca['rchar'] = ca['rchar'].replace(np.nan,median_2)
ca['rchar'].isnull().sum()
# Out:
# 0

# %%
# To Check for null values in the dataset
ca.isnull().sum()
# Out:
# lread       0
# lwrite      0
# scall       0
# sread       0
# swrite      0
# fork        0
# exec        0
# rchar       0
# wchar       0
# pgout       0
# ppgout      0
# pgfree      0
# pgscan      0
# atch        0
# pgin        0
# ppgin       0
# pflt        0
# vflt        0
# runqsz      0
# freemem     0
# freeswap    0
# usr         0
# dtype: int64

# %% [markdown]
# ## Insight:
#     * Null value is replaced by the median value for rchar & wchar in the dataset.

# %%
# To view the unique values for categorical variables
ca['runqsz'].value_counts()
# Out:
# Not_CPU_Bound    4331
# CPU_Bound        3861
# Name: runqsz, dtype: int64

# %%
# To view info of the dataset
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lread     8192 non-null   int64
#  1   lwrite    8192 non-null   int64
#  2   scall     8192 non-null   int64
#  3   sread     8192 non-null   int64
#  4   swrite    8192 non-null   int64
#  5   fork      8192 non-null   float64
#  6   exec      8192 non-null   float64
#  7   rchar     8192 non-null   float64
#  8   wchar     8192 non-null   float64
#  9   pgout     8192 non-null   float64
#  10  ppgout    8192 non-null   float64
#  11  pgfree    8192 non-null   float64
#  12  pgscan    8192 non-null   float64
#  13  atch      8192 non-null   float64
#  14  pgin      8192 non-null   float64
#  15  ppgin     8192 non-null   float64
#  16  pflt      8192 non-null   float64
#  17  vflt      8192 non-null   float64
#  18  runqsz    8192 non-null   object
#  19  freemem   8192 non-null   int64
# ...

# %%
# To Check the dulipciate values in the dataset
ca.duplicated().sum()
# Out:
# 0

# %%
# To Check for duplicate values in the dataset

dups = ca.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

ca[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [lread, lwrite, scall, sread, swrite, fork, exec, rchar, wchar, pgout, ppgout, pgfree, pgscan, atch, pgin, ppgin, pflt, vflt, runqsz, freemem, freeswap, usr]
# Index: []
#
# [0 rows x 22 columns]

# %%
# To Check for null values in the dataset
ca.isnull().sum()
# Out:
# lread       0
# lwrite      0
# scall       0
# sread       0
# swrite      0
# fork        0
# exec        0
# rchar       0
# wchar       0
# pgout       0
# ppgout      0
# pgfree      0
# pgscan      0
# atch        0
# pgin        0
# ppgin       0
# pflt        0
# vflt        0
# runqsz      0
# freemem     0
# freeswap    0
# usr         0
# dtype: int64

# %%
# To check the zero value present in the dataset
print('* of records with 0 value in lread: {:.2%}'.format((ca[ca.lread == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in lwrite: {:.2%}'.format((ca[ca.lwrite == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in scall: {:.2%}'.format((ca[ca.scall == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in sread: {:.2%}'.format((ca[ca.sread == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in swrite: {:.2%}'.format((ca[ca.swrite == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in fork: {:.2%}'.format((ca[ca.fork == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in exec: {:.2%}'.format((ca[ca.exec == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in rchar: {:.2%}'.format((ca[ca.rchar == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in wchar: {:.2%}'.format((ca[ca.wchar == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in pgout: {:.2%}'.format((ca[ca.pgout == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in ppgout: {:.2%}'.format((ca[ca.ppgout == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in pgfree: {:.2%}'.format((ca[ca.pgfree == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in pgscan: {:.2%}'.format((ca[ca.pgscan == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in atch: {:.2%}'.format((ca[ca.atch == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in pgin: {:.2%}'.format((ca[ca.pgin == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in ppgin: {:.2%}'.format((ca[ca.ppgin == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in pflt: {:.2%}'.format((ca[ca.pflt == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in vflt: {:.2%}'.format((ca[ca.vflt == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in runqsz: {:.2%}'.format((ca[ca.runqsz == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in freemem: {:.2%}'.format((ca[ca.freemem == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in freeswap: {:.2%}'.format((ca[ca.freeswap == 0].shape[0])/ca.shape[0]))
print('* of records with 0 value in usr: {:.2%}'.format((ca[ca.usr == 0].shape[0])/ca.shape[0]))
# Out:
# * of records with 0 value in lread: 8.24%
# * of records with 0 value in lwrite: 32.76%
# * of records with 0 value in scall: 0.00%
# * of records with 0 value in sread: 0.00%
# * of records with 0 value in swrite: 0.00%
# * of records with 0 value in fork: 0.26%
# * of records with 0 value in exec: 0.26%
# * of records with 0 value in rchar: 0.00%
# * of records with 0 value in wchar: 0.00%
# * of records with 0 value in pgout: 59.55%
# * of records with 0 value in ppgout: 59.55%
# * of records with 0 value in pgfree: 59.44%
# * of records with 0 value in pgscan: 78.71%
# * of records with 0 value in atch: 55.85%
# * of records with 0 value in pgin: 14.89%
# * of records with 0 value in ppgin: 14.89%
# * of records with 0 value in pflt: 0.04%
# * of records with 0 value in vflt: 0.00%
# * of records with 0 value in runqsz: 0.00%
# * of records with 0 value in freemem: 0.00%
# * of records with 0 value in freeswap: 0.00%
# * of records with 0 value in usr: 3.45%

# %% [markdown]
# ## Insight:
#     * The variables columns pgout,ppgout,pgfree,pgscan,atch have atleast 50% of the values is having 0 and dropping the columns.
#     * Yes we need to drop the columns is having more 50% of values is having 0. The variable columns is dropped from the dataset and columns details are pgout, ppgout, pgfree, pgscan and atch
#     * The remaining variables columns lread, lwrite, fork, exec, pgin, ppgin, usr & pflt is having minimum values of 0. Needs to cleanup the columns
#     * Treat the columns is having minimum values of 0 with replace value using median function

# %%
# Drop the columns is having more than 50% values is having 0
ca.drop(['pgout','ppgout','pgfree','pgscan','atch'], axis=1, inplace=True)
ca.head()
# Out:
#    lread  lwrite  scall  sread  swrite  fork  exec     rchar    wchar  pgin  \
# 0      1       0   2147     79      68   0.2   0.2   40671.0  53995.0   1.6
# 1      0       0    170     18      21   0.2   0.2     448.0   8385.0   0.0
# 2     15       3   2162    159     119   2.0   2.4  125473.5  31950.0   6.0
# 3      0       0    160     12      16   0.2   0.2  125473.5   8670.0   0.2
# 4      5       1    330     39      38   0.4   0.4  125473.5  12185.0   1.0
#
#    ppgin    pflt    vflt         runqsz  freemem  freeswap  usr
# 0    2.6   16.00   26.40      CPU_Bound     4670   1730946   95
# 1    0.0   15.63   16.83  Not_CPU_Bound     7278   1869002   97
# 2    9.4  150.20  220.20  Not_CPU_Bound      702   1021237   87
# 3    0.2   15.60   16.80  Not_CPU_Bound     7248   1863704   98
# 4    1.2   37.80   47.60  Not_CPU_Bound      633   1760253   90

# %%
# Replace the 0 value into median
ca.lread.replace(to_replace=0, value=ca.lread.median(),inplace=True)
ca.lwrite.replace(to_replace=0, value=ca.lwrite.median(),inplace=True)
ca.fork.replace(to_replace=0,value=ca.fork.median(),inplace=True)
ca.exec.replace(to_replace=0,value=ca.exec.median(),inplace=True)
ca.pgin.replace(to_replace=0,value=ca.pgin.median(),inplace=True)
ca.ppgin.replace(to_replace=0,value=ca.ppgin.median(),inplace=True)
ca.pflt.replace(to_replace=0,value=ca.pflt.median(),inplace=True)
ca.usr.replace(to_replace=0,value=ca.usr.median(),inplace=True)

# %%
# To print number of rows and columns present in the dataset
print("no.of rows: ",ca.shape[0], "no.of columns:",ca.shape[1])
# Out:
# no.of rows:  8192 no.of columns: 17

# %%
# To view info of the dataset
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lread     8192 non-null   int64
#  1   lwrite    8192 non-null   int64
#  2   scall     8192 non-null   int64
#  3   sread     8192 non-null   int64
#  4   swrite    8192 non-null   int64
#  5   fork      8192 non-null   float64
#  6   exec      8192 non-null   float64
#  7   rchar     8192 non-null   float64
#  8   wchar     8192 non-null   float64
#  9   pgin      8192 non-null   float64
#  10  ppgin     8192 non-null   float64
#  11  pflt      8192 non-null   float64
#  12  vflt      8192 non-null   float64
#  13  runqsz    8192 non-null   object
#  14  freemem   8192 non-null   int64
#  15  freeswap  8192 non-null   int64
#  16  usr       8192 non-null   int64
# dtypes: float64(8), int64(8), object(1)
# memory usage: 1.1+ MB

# %%
# To Check for null values in the dataset
ca.isnull().sum()
# Out:
# lread       0
# lwrite      0
# scall       0
# sread       0
# swrite      0
# fork        0
# exec        0
# rchar       0
# wchar       0
# pgin        0
# ppgin       0
# pflt        0
# vflt        0
# runqsz      0
# freemem     0
# freeswap    0
# usr         0
# dtype: int64

# %%
# To view describe the dataset
ca.describe().T
# Out:
#            count          mean            std      min         25%        50%  \
# lread     8192.0  2.013647e+01      53.176752     1.00        3.00        7.0
# lwrite    8192.0  1.343384e+01      29.751410     1.00        1.00        1.0
# scall     8192.0  2.306318e+03    1633.617322   109.00     1012.00     2051.5
# sread     8192.0  2.104800e+02     198.980146     6.00       86.00      166.0
# swrite    8192.0  1.500582e+02     160.478980     7.00       63.00      117.0
# fork      8192.0  1.886605e+00       2.478264     0.19        0.40        0.8
# exec      8192.0  2.795074e+00       5.211161     0.19        0.20        1.2
# rchar     8192.0  1.964728e+05  238446.012054   278.00    34860.50   125473.5
# wchar     8192.0  9.581275e+04  140728.464118  1498.00    22977.75    46619.0
# pgin      8192.0  8.694952e+00      13.660319     0.19        1.60        2.8
# ppgin     8192.0  1.295450e+01      22.006000     0.20        2.00        3.8
# ...

# %% [markdown]
# ## Insight:
#     * Database administrator would be checking the size of the dataset using '.shape' which throw output for number of rows and number of columns and using '.info()' for checking the type of variables in the dataset.
#     * There are 8192 number of rows and 22 columns in the dataset.
#     * There are 8 in int64, 13 in float64 and 1 in object present in the dataset
#     * No duplicate records is present in the dataset
#     * No Null value present in the dataset

# %% [markdown]
# # Outlier Treatment
#
# **To check for outliers, we will be plotting the box plots.**

# %%
ca_num = ca.select_dtypes(include = ['float64', 'int64'])

# %%
# Check the box plot with outliers
plt.figure(figsize=(15,15))
feature_list = ca_num.columns
for i in range (len(feature_list)):
    plt.subplot(4, 4, i+1)
    sns.boxplot(y=ca_num[feature_list[i]],data=ca_num)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %% [markdown]
# ## Insights:
#     * Yes outliners has been detected in all items **These outliers value needs to be treated and there are several ways of treating them:
#     * Drop the outlier value
#     * Replace the outlier value using the IQR

# %%
# Define a function which results the upper and lower limit to detect outliers for each fields
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
# Cap & floor the values beyond the outlier boundaries
for i in feature_list:
    LL,UL = remove_outlier(ca_num[i])
    ca_num[i] = np.where (ca_num[i] > UL,UL, ca_num[i])
    ca_num[i] = np.where (ca_num[i] < LL,LL, ca_num[i])

# %%
# Check the box plot after treating outliers
plt.figure(figsize=(15,15))
feature_list = ca_num.columns
for i in range (len(feature_list)):
    plt.subplot(4, 4, i+1)
    sns.boxplot(y=ca_num[feature_list[i]],data=ca_num)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %% [markdown]
# # Univariate Analysis

# %%
# Plot the histogram plot for dataset
ca.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Plot the scatter plot between the usr and rchar
fig_dims=(12,5)
fig = plt.subplots(figsize=fig_dims)
plt.scatter(x='usr',y='rchar',  data = ca)
plt.title('cpu run in usr mode vs rchar ',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the usr and wchar
fig_dims=(12,5)
fig = plt.subplots(figsize=fig_dims)
plt.scatter(x='usr',y='wchar',  data = ca)
plt.title('cpu run in usr mode vs wchar ',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the usr and fork
fig_dims=(12,5)
fig = plt.subplots(figsize=fig_dims)
plt.scatter(x='usr',y='fork',  data = ca)
plt.title('cpu run in usr mode vs fork ',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the usr and sread
fig_dims=(12,5)
fig = plt.subplots(figsize=fig_dims)
plt.scatter(x='usr',y='sread',  data = ca)
plt.title('cpu run in usr mode vs sread ',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the usr and swrite
fig_dims=(12,5)
fig = plt.subplots(figsize=fig_dims)
plt.scatter(x='usr',y='swrite',  data = ca)
plt.title('cpu run in usr mode vs swrite ',fontsize=14)
plt.show();

# %%
# Plot the bar plot between the usr and freeswap
fig_dims=(15,8)
fig = plt.subplots(figsize=fig_dims)
sns.barplot(x='usr',y='freeswap', data= ca)
plt.title('cpu run in usr mode vs freeswap ',fontsize=14)
plt.show();

# %%
# Plot the bar plot between the usr and freemem
fig_dims=(15,8)
fig = plt.subplots(figsize=fig_dims)
sns.barplot(x='usr',y='freemem',  data = ca)
plt.title('cpu run in usr mode vs freemem ',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the lread and lwrite by runqsz
plt.figure(figsize=(10,7))
sns.scatterplot(x='lread', y= 'lwrite',data=ca,hue='runqsz')
plt.title('lread vs lwrite by runqsz ',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the sread and swrite by runqsz
plt.figure(figsize=(10,7))
sns.scatterplot(x='sread', y='swrite',data=ca,hue='runqsz')
plt.title('sread vs swrite by runqsz',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the exec and fork by runqsz
plt.figure(figsize=(10,7))
sns.scatterplot(x='exec', y='fork',data=ca,hue='runqsz')
plt.title('exec vs fork by runqsz',fontsize=14)
plt.show();

# %%
# Plot the scatter plot between the vflt and pflt by runqsz
plt.figure(figsize=(10,7))
sns.scatterplot(x='vflt', y='pflt',data=ca,hue='runqsz')
plt.title('vflt vs pflt by runqsz',fontsize=14)
plt.show();

# %% [markdown]
# # Multivariate Analysis

# %%
# Checking for Correlations
ca.corr()
# Out:
#              lread    lwrite     scall     sread    swrite      fork  \
# lread     1.000000  0.530386  0.183427  0.126584  0.114870  0.133405
# lwrite    0.530386  1.000000  0.141395  0.126944  0.100594  0.051009
# scall     0.183427  0.141395  1.000000  0.696887  0.619984  0.446353
# sread     0.126584  0.126944  0.696887  1.000000  0.881069  0.416407
# swrite    0.114870  0.100594  0.619984  0.881069  1.000000  0.376697
# fork      0.133405  0.051009  0.446353  0.416407  0.376697  1.000000
# exec      0.106007  0.037071  0.308564  0.163740  0.103371  0.763830
# rchar     0.102754  0.112933  0.349148  0.499998  0.330156  0.279310
# wchar     0.077941  0.089894  0.273796  0.401427  0.393929  0.060848
# pgin      0.181911  0.084688  0.221049  0.192784  0.135587  0.154433
# ppgin     0.153721  0.083517  0.201275  0.198128  0.134523  0.124070
# pflt      0.129323  0.065199  0.481594  0.451896  0.396476  0.930780
# vflt      0.157289  0.093053  0.531760  0.491045  0.416571  0.939091
# ...

# %%
# Multivariate Analysis
plt.figure(figsize=(12,7))
sns.heatmap(ca.corr(), annot=True,mask=np.triu(ca.corr(),+1));
plt.show()

# %%
# Encoding independent variable
ca = pd.get_dummies(ca, columns=['runqsz'],drop_first=True)

# %%
# To view the top 5 record using head function of the dataset
ca.head()
# Out:
#    lread  lwrite  scall  sread  swrite  fork  exec     rchar    wchar  pgin  \
# 0      1       1   2147     79      68   0.2   0.2   40671.0  53995.0   1.6
# 1      7       1    170     18      21   0.2   0.2     448.0   8385.0   2.8
# 2     15       3   2162    159     119   2.0   2.4  125473.5  31950.0   6.0
# 3      7       1    160     12      16   0.2   0.2  125473.5   8670.0   0.2
# 4      5       1    330     39      38   0.4   0.4  125473.5  12185.0   1.0
#
#    ppgin    pflt    vflt  freemem  freeswap  usr  runqsz_Not_CPU_Bound
# 0    2.6   16.00   26.40     4670   1730946   95                     0
# 1    3.8   15.63   16.83     7278   1869002   97                     1
# 2    9.4  150.20  220.20      702   1021237   87                     1
# 3    0.2   15.60   16.80     7248   1863704   98                     1
# 4    1.2   37.80   47.60      633   1760253   90                     1

# %%
# To view info of the dataset
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lread                 8192 non-null   int64
#  1   lwrite                8192 non-null   int64
#  2   scall                 8192 non-null   int64
#  3   sread                 8192 non-null   int64
#  4   swrite                8192 non-null   int64
#  5   fork                  8192 non-null   float64
#  6   exec                  8192 non-null   float64
#  7   rchar                 8192 non-null   float64
#  8   wchar                 8192 non-null   float64
#  9   pgin                  8192 non-null   float64
#  10  ppgin                 8192 non-null   float64
#  11  pflt                  8192 non-null   float64
#  12  vflt                  8192 non-null   float64
#  13  freemem               8192 non-null   int64
#  14  freeswap              8192 non-null   int64
# ...

# %% [markdown]
# # Train-Test Split

# %%
# Creating a copy of the original data frame
data_ds = ca.copy()

# %%
# Copy all the predictor variables into X dataframe
X = data_ds.drop('usr', axis=1)

# Copy target into the y dataframe. 
y = data_ds[['usr']]

# %%
# To view the top 5 record using head function of the dataset
X.head()
# Out:
#    lread  lwrite  scall  sread  swrite  fork  exec     rchar    wchar  pgin  \
# 0      1       1   2147     79      68   0.2   0.2   40671.0  53995.0   1.6
# 1      7       1    170     18      21   0.2   0.2     448.0   8385.0   2.8
# 2     15       3   2162    159     119   2.0   2.4  125473.5  31950.0   6.0
# 3      7       1    160     12      16   0.2   0.2  125473.5   8670.0   0.2
# 4      5       1    330     39      38   0.4   0.4  125473.5  12185.0   1.0
#
#    ppgin    pflt    vflt  freemem  freeswap  runqsz_Not_CPU_Bound
# 0    2.6   16.00   26.40     4670   1730946                     0
# 1    3.8   15.63   16.83     7278   1869002                     1
# 2    9.4  150.20  220.20      702   1021237                     1
# 3    0.2   15.60   16.80     7248   1863704                     1
# 4    1.2   37.80   47.60      633   1760253                     1

# %%
# Import the train_test_split library
# Split X and y into training and test set in 70:30 ratio
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %% [markdown]
# # Linear Regression Model

# %%
# Import the LinearRegression libary file
from sklearn.linear_model import LinearRegression

# %%
# invoke the LinearRegression function and find the bestfit model on training data
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Let us explore the coefficients for each of the independent attributes
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for lread is -0.011900566545768987
# The coefficient for lwrite is -0.002382139356811826
# The coefficient for scall is -0.001405192374101927
# The coefficient for sread is 0.0006411282096700219
# The coefficient for swrite is -0.003931752249884772
# The coefficient for fork is 0.2043696725744861
# The coefficient for exec is -0.32419117788998597
# The coefficient for rchar is -1.1965134149888863e-06
# The coefficient for wchar is -5.1359696811800335e-06
# The coefficient for pgin is -0.013921553275936208
# The coefficient for ppgin is -0.05295469120861771
# The coefficient for pflt is -0.01764265064165738
# The coefficient for vflt is -0.015474555520646915
# The coefficient for freemem is 0.00021261163686064945
# The coefficient for freeswap is -3.669252004797546e-07
# The coefficient for runqsz_Not_CPU_Bound is -0.12111793824531514

# %%
# Let us check the intercept for the model
intercept = regression_model.intercept_[0]
print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 98.04063083065795

# %%
# R square on training data
regression_model.score(X_train, y_train)
# Out:
# 0.7990928753603382

# %%
# R square on testing data
regression_model.score(X_test, y_test)
# Out:
# 0.7817552563251355

# %%
# Import the metrics library
from sklearn import metrics

# %%
#RMSE on Training data
predicted_train=regression_model.fit(X_train, y_train).predict(X_train)
np.sqrt(metrics.mean_squared_error(y_train,predicted_train))
# Out:
# 4.223764847012626

# %%
#RMSE on Testing data
predicted_test=regression_model.fit(X_train, y_train).predict(X_test)
np.sqrt(metrics.mean_squared_error(y_test,predicted_test))
# Out:
# 4.202461580650129

# %% [markdown]
# ### Linear Regression using statsmodels(OLS)

# %%
import statsmodels.api as sm

# %%
X_train=sm.add_constant(X_train)
X_test=sm.add_constant(X_test)

# %%
model = sm.OLS(y_train,X_train).fit()
model

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    usr   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     1421.
# Date:                Wed, 23 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:14:37   Log-Likelihood:                -16397.
# No. Observations:                5734   AIC:                         3.283e+04
# Df Residuals:                    5717   BIC:                         3.294e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
#Calculate MSE on train
predicted_train=model.predict(X_train)
mse=metrics.mean_squared_error(y_train,predicted_train)

# %%
#RMSE on train 
np.sqrt(mse)
# Out:
# 4.223764847012626

# %%
# Prediction on Test data
y_pred = model.predict(X_test)

# %%
#Calculate MSE on test
mse=metrics.mean_squared_error(y_test,y_pred)

# %%
#RMSE on test
np.sqrt(mse)
# Out:
# 4.20246158065015

# %%
#Calculate MSE on test
mse=metrics.mean_squared_error(y_test,y_pred)
np.sqrt(mse)
# Out:
# 4.20246158065015

# %%
# Plot the scatterplot for the y_test vs y_pred
plt.figure(figsize=(12,8))
plt.scatter(y_test, y_pred)
plt.title('y_test vs y_pred ',fontsize=14)
plt.show()

# %%
# To calculate the predictive and residual
data_ds=y_test.copy()
data_ds['predictive']=y_pred
data_ds['residual']=data_ds['usr']-data_ds['predictive']
data_ds.head()
# Out:
#       usr  predictive  residual
# 3894   95   95.252590 -0.252590
# 4276   95   94.830537  0.169463
# 3414   89   90.495571 -1.495571
# 4165   80   79.370512  0.629488
# 7385   79   81.698794 -2.698794

# %%
# Plot the scatterplot for the predictive vs residual
plt.figure(figsize=(10,7))
plt.scatter(data_ds['predictive'],data_ds['residual'],color='green')
plt.title('predictive vs residual ',fontsize=14)
plt.show()

# %%
# Plot the histogram plot for new dataframe
plt.figure(figsize=(10,7))
sns.distplot(data_ds.residual);
plt.show()
# Out:
# C:\Users\Umashankar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i,j in np.array(model.params.reset_index()):
    print('({}) * {} +'.format(round(j,4),i),end=' ')
# Out:
# (98.0406) * const + (-0.0119) * lread + (-0.0024) * lwrite + (-0.0014) * scall + (0.0006) * sread + (-0.0039) * swrite + (0.2044) * fork + (-0.3242) * exec + (-0.0) * rchar + (-0.0) * wchar + (-0.0139) * pgin + (-0.053) * ppgin + (-0.0176) * pflt + (-0.0155) * vflt + (0.0002) * freemem + (-0.0) * freeswap + (-0.1211) * runqsz_Not_CPU_Bound +

# %% [markdown]
# # Conclusion:
#     * Linear Regression Equation is (98.0406) * const + (-0.0119) * lread + (-0.0024) * lwrite + (-0.0014) * scall + (0.0006) * sread + (-0.0039) * swrite + (0.2044) * fork + (-0.3242) * exec + (-0.0) * rchar + (-0.0) * wchar + (-0.0139) * pgin + (-0.053) * ppgin + (-0.0176) * pflt + (-0.0155) * vflt + (0.0002) * freemem + (-0.0) * freeswap + (-0.1211) * runqsz_Not_CPU_Bound
#     * The R-squared value tells us that our model can explain 0.799% of the variance in the training set.
#     * The Adj. R-squared value tells us that our model can explain 0.799% of the variance in the training set.

# %%
# Import the library file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt   
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix

# %%
# Loading the data set
cmd= pd.read_excel('Contraceptive_method_dataset.xlsx')

# %%
# To view the top 5 record using head function of the dataset
cmd.head()
# Out:
#    Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0      24.0         Primary         Secondary                  3.0
# 1      45.0      Uneducated         Secondary                 10.0
# 2      43.0         Primary         Secondary                  7.0
# 3      42.0       Secondary           Primary                  9.0
# 4      36.0       Secondary         Secondary                  8.0
#
#   Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# 0   Scientology           No                   2                     High
# 1   Scientology           No                   3                Very High
# 2   Scientology           No                   3                Very High
# 3   Scientology           No                   3                     High
# 4   Scientology           No                   3                      Low
#
#   Media_exposure  Contraceptive_method_used
# 0         Exposed                        No
# ...

# %%
# To view the last 5 record using tail function of the dataset
cmd.tail()
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 1468      33.0        Tertiary          Tertiary                  NaN
# 1469      33.0        Tertiary          Tertiary                  NaN
# 1470      39.0       Secondary         Secondary                  NaN
# 1471      33.0       Secondary         Secondary                  NaN
# 1472      17.0       Secondary         Secondary                  1.0
#
#      Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# 1468   Scientology          Yes                   2                Very High
# 1469   Scientology           No                   1                Very High
# 1470   Scientology          Yes                   1                Very High
# 1471   Scientology          Yes                   2                      Low
# 1472   Scientology           No                   2                Very High
#
#      Media_exposure  Contraceptive_method_used
# ...

# %%
# To print number of rows and columns present in the dataset
print("no.of rows: ",cmd.shape[0], "no.of columns:",cmd.shape[1])
# Out:
# no.of rows:  1473 no.of columns: 10

# %%
# To view the shape of the dataset
cmd.shape
# Out:
# (1473, 10)

# %%
# To view describe the dataset
cmd.describe().T
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# Wife_age             1402.0  32.606277  8.274927  16.0  26.0  32.0  39.0  49.0
# No_of_children_born  1452.0   3.254132  2.365212   0.0   1.0   3.0   4.0  16.0
# Husband_Occupation   1473.0   2.137814  0.864857   1.0   1.0   2.0   3.0   4.0

# %%
# To view info of the dataset
cmd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473 entries, 0 to 1472
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Wife_age                   1402 non-null   float64
#  1   Wife_ education            1473 non-null   object
#  2   Husband_education          1473 non-null   object
#  3   No_of_children_born        1452 non-null   float64
#  4   Wife_religion              1473 non-null   object
#  5   Wife_Working               1473 non-null   object
#  6   Husband_Occupation         1473 non-null   int64
#  7   Standard_of_living_index   1473 non-null   object
#  8   Media_exposure             1473 non-null   object
#  9   Contraceptive_method_used  1473 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 115.2+ KB

# %%
# To Check for null values in the dataset
cmd.isnull().sum()
# Out:
# Wife_age                     71
# Wife_ education               0
# Husband_education             0
# No_of_children_born          21
# Wife_religion                 0
# Wife_Working                  0
# Husband_Occupation            0
# Standard_of_living_index      0
# Media_exposure                0
# Contraceptive_method_used     0
# dtype: int64

# %%
# To Check the dulipciate values in the dataset
cmd.duplicated().sum()
# Out:
# 80

# %%
# To Check for duplicate values in the dataset

dups = cmd.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

cmd[dups]
# Out:
# Number of duplicate rows = 80
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 79        38.0        Tertiary          Tertiary                  1.0
# 167       26.0        Tertiary          Tertiary                  1.0
# 224       47.0        Tertiary          Tertiary                  4.0
# 270       30.0        Tertiary          Tertiary                  2.0
# 299       26.0        Tertiary          Tertiary                  1.0
# ...        ...             ...               ...                  ...
# 1367      44.0        Tertiary          Tertiary                  5.0
# 1387       NaN       Secondary          Tertiary                  2.0
# 1423       NaN        Tertiary          Tertiary                  2.0
# 1440       NaN        Tertiary          Tertiary                  1.0
# 1447       NaN        Tertiary          Tertiary                  2.0
#
#         Wife_religion Wife_Working  Husband_Occupation  \
# ...

# %% [markdown]
# ## Insight before treating with the Null values and Duplicate values:
#     * 1) Database administrator would be checking the size of the dataset using '.shape' which throw output for number of rows and number of columns and using '.info()' for checking the type of variables in the dataset.
#     * 2) There are 1473 number of rows and 10 columns in the dataset.
#     * 3) There are 1 in int64, 2 in float64 and 7 in object present in the dataset
#     * 4) Duplicate records is present in the dataset with 80
#     * 5) Null value present in the dataset for wife_age is having 71 rows & No_of_children_born  is having 21 rows

# %%
# Removing the duplicate value
cmd.drop_duplicates(inplace=True)

# %%
# To Check for duplicate values after drop in the dataset

dups = cmd.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

cmd[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [Wife_age, Wife_ education, Husband_education, No_of_children_born, Wife_religion, Wife_Working, Husband_Occupation, Standard_of_living_index, Media_exposure , Contraceptive_method_used]
# Index: []

# %%
# To print number of rows and columns present in the dataset after removing the duplicate values
print("no.of rows: ",cmd.shape[0], "no.of columns:",cmd.shape[1])
# Out:
# no.of rows:  1393 no.of columns: 10

# %%
# To view describe the dataset
cmd.describe().T
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# Wife_age             1326.0  32.557315  8.289259  16.0  26.0  32.0  39.0  49.0
# No_of_children_born  1372.0   3.290816  2.399697   0.0   1.0   3.0   5.0  16.0
# Husband_Occupation   1393.0   2.174444  0.854590   1.0   1.0   2.0   3.0   4.0

# %%
# To Check for null values in the dataset
cmd.isnull().sum()
# Out:
# Wife_age                     67
# Wife_ education               0
# Husband_education             0
# No_of_children_born          21
# Wife_religion                 0
# Wife_Working                  0
# Husband_Occupation            0
# Standard_of_living_index      0
# Media_exposure                0
# Contraceptive_method_used     0
# dtype: int64

# %%
# Replace the null value with Median
cmd[['Wife_age', 'No_of_children_born']] = cmd[['Wife_age', 'No_of_children_born']].fillna(cmd[['Wife_age', 'No_of_children_born']].median())

# %%
# To Check for null values in the dataset
cmd.isnull().sum()
# Out:
# Wife_age                     0
# Wife_ education              0
# Husband_education            0
# No_of_children_born          0
# Wife_religion                0
# Wife_Working                 0
# Husband_Occupation           0
# Standard_of_living_index     0
# Media_exposure               0
# Contraceptive_method_used    0
# dtype: int64

# %%
# To view describe the dataset
cmd.describe().T
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# Wife_age             1393.0  32.530510  8.088188  16.0  26.0  32.0  38.0  49.0
# No_of_children_born  1393.0   3.286432  2.381791   0.0   1.0   3.0   5.0  16.0
# Husband_Occupation   1393.0   2.174444  0.854590   1.0   1.0   2.0   3.0   4.0

# %% [markdown]
# ## Insight: After removing the duplicate values and replacing the null value with median
# * 1) Database administrator would be checking the size of the dataset using '.shape' which throw output for number of rows and number of columns and using '.info()' for checking the type of variables in the dataset.
# * 2) There are 1393 number of rows and 10 columns in the dataset.
# * 3) There are 1 in int64, 2 in float64 and 7 in object present in the dataset
# * 4) No Duplicate records is present in the dataset
# * 5) No Null value present in the dataset

# %% [markdown]
# # Outlier Treatment
# To check for outliers, we will be plotting the box plots.

# %%
cmd_num = cmd.select_dtypes(include = ['float64', 'int64'])

# %%
# Check the presence of outliers in the each features
plt.figure(figsize=(12,8))
feature_list = cmd_num.columns
for i in range (len(feature_list)):
    plt.subplot(2, 2, i+1)
    sns.boxplot(y=cmd_num[feature_list[i]],data=cmd_num)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %% [markdown]
# ## Insights:
#     * Yes outliners has been detected in all items **These outliers value needs to be treated and there are several ways of treating them:
#     * Drop the outlier value
#     *Replace the outlier value using the IQR

# %%
# Define a function which results the upper and lower limit to detect outliers for each fields
def remove_outlier(col):
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
# Cap & floor the values beyond the outlier boundaries
for i in feature_list:
    LL,UL = remove_outlier(cmd_num[i])
    cmd_num[i] = np.where (cmd_num[i] > UL,UL, cmd_num[i])
    cmd_num[i] = np.where (cmd_num[i] < LL,LL, cmd_num[i])

# %%
# Check the presence of outliers in the each features
plt.figure(figsize=(12,8))
feature_list = cmd_num.columns
for i in range (len(feature_list)):
    plt.subplot(2, 2, i+1)
    sns.boxplot(y=cmd_num[feature_list[i]],data=cmd_num)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %%
# Univariate Analysis
plt.figure(figsize=(12,15))
feature_list = cmd.columns
for i in range (len(feature_list)):
    plt.subplot(4, 3, i+1)
    sns.histplot(y=cmd[feature_list[i]],data=cmd)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %%
# Bivariate Analysis
plt.figure(figsize=(12,8))
sns.pairplot(cmd, diag_kind="kde")
plt.show()

# %% [markdown]
# ## Checking for Correlations

# %%
cmd.corr()
# Out:
#                      Wife_age  No_of_children_born  Husband_Occupation
# Wife_age             1.000000             0.528428           -0.187070
# No_of_children_born  0.528428             1.000000           -0.024213
# Husband_Occupation  -0.187070            -0.024213            1.000000

# %%
# Multivariate Analysis
plt.figure(figsize=(12,8))
sns.heatmap(cmd.iloc[:, 0:10].corr(),annot=True)
plt.show()

# %% [markdown]
# # Converting all objects to categorical codes

# %%
cmd['Wife_ education']=np.where(cmd['Wife_ education'] =='Uneducated', 1, cmd['Wife_ education'])
cmd['Wife_ education']=np.where(cmd['Wife_ education'] =='Primary', 2, cmd['Wife_ education'])
cmd['Wife_ education']=np.where(cmd['Wife_ education'] =='Secondary', 3, cmd['Wife_ education'])
cmd['Wife_ education']=np.where(cmd['Wife_ education'] =='Tertiary', 4, cmd['Wife_ education'])

# %%
cmd['Husband_education']=np.where(cmd['Husband_education'] =='Uneducated', 1, cmd['Husband_education'])
cmd['Husband_education']=np.where(cmd['Husband_education'] =='Primary', 2, cmd['Husband_education'])
cmd['Husband_education']=np.where(cmd['Husband_education'] =='Secondary', 3, cmd['Husband_education'])
cmd['Husband_education']=np.where(cmd['Husband_education'] =='Tertiary', 4, cmd['Husband_education'])

# %%
cmd['Standard_of_living_index']=np.where(cmd['Standard_of_living_index'] =='Very Low', 1, cmd['Standard_of_living_index'])
cmd['Standard_of_living_index']=np.where(cmd['Standard_of_living_index'] =='Low', 2, cmd['Standard_of_living_index'])
cmd['Standard_of_living_index']=np.where(cmd['Standard_of_living_index'] =='High', 3, cmd['Standard_of_living_index'])
cmd['Standard_of_living_index']=np.where(cmd['Standard_of_living_index'] =='Very High', 4, cmd['Standard_of_living_index'])

# %%
cmd['Wife_Working']=np.where(cmd['Wife_Working'] =='No', 0, cmd['Wife_Working'])
cmd['Wife_Working']=np.where(cmd['Wife_Working'] =='Yes', 1, cmd['Wife_Working'])

# %%
cmd['Contraceptive_method_used']=np.where(cmd['Contraceptive_method_used'] =='No', 0, cmd['Contraceptive_method_used'])
cmd['Contraceptive_method_used']=np.where(cmd['Contraceptive_method_used'] =='Yes', 1, cmd['Contraceptive_method_used'])

# %%
cmd['Media_exposure ']=np.where(cmd['Media_exposure '] =='Not-Exposed', 0, cmd['Media_exposure '])
cmd['Media_exposure ']=np.where(cmd['Media_exposure '] =='Exposed', 1, cmd['Media_exposure '])

# %%
cmd['Wife_religion']=np.where(cmd['Wife_religion'] =='Non-Scientology', 0, cmd['Wife_religion'])
cmd['Wife_religion']=np.where(cmd['Wife_religion'] =='Scientology', 1, cmd['Wife_religion'])

# %%
# To view the top 5 record using head function of the dataset
cmd.head()
# Out:
#    Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0      24.0               2                 3                  3.0
# 1      45.0               1                 3                 10.0
# 2      43.0               2                 3                  7.0
# 3      42.0               3                 2                  9.0
# 4      36.0               3                 3                  8.0
#
#   Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# 0             1            0                   2                        3
# 1             1            0                   3                        4
# 2             1            0                   3                        4
# 3             1            0                   3                        3
# 4             1            0                   3                        2
#
#   Media_exposure  Contraceptive_method_used
# 0               1                         0
# ...

# %%
# To view describe the dataset
cmd.describe(include='all').T
# Out:
#                             count  unique  top    freq       mean       std  \
# Wife_age                   1393.0     NaN  NaN     NaN  32.530510  8.088188
# Wife_ education            1393.0     4.0  4.0   515.0        NaN       NaN
# Husband_education          1393.0     4.0  4.0   827.0        NaN       NaN
# No_of_children_born        1393.0     NaN  NaN     NaN   3.286432  2.381791
# Wife_religion              1393.0     2.0  1.0  1186.0        NaN       NaN
# Wife_Working               1393.0     2.0  0.0  1043.0        NaN       NaN
# Husband_Occupation         1393.0     NaN  NaN     NaN   2.174444  0.854590
# Standard_of_living_index   1393.0     4.0  4.0   618.0        NaN       NaN
# Media_exposure             1393.0     2.0  1.0  1284.0        NaN       NaN
# Contraceptive_method_used  1393.0     2.0  1.0   779.0        NaN       NaN
#
#                             min   25%   50%   75%   max
# Wife_age                   16.0  26.0  32.0  38.0  49.0
# ...

# %%
# To view info of the dataset
cmd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1393 entries, 0 to 1472
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Wife_age                   1393 non-null   float64
#  1   Wife_ education            1393 non-null   object
#  2   Husband_education          1393 non-null   object
#  3   No_of_children_born        1393 non-null   float64
#  4   Wife_religion              1393 non-null   object
#  5   Wife_Working               1393 non-null   object
#  6   Husband_Occupation         1393 non-null   int64
#  7   Standard_of_living_index   1393 non-null   object
#  8   Media_exposure             1393 non-null   object
#  9   Contraceptive_method_used  1393 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 152.0+ KB

# %%
# convert the object into int8 datatype
for feature in cmd.columns: 
    if cmd[feature].dtype == 'object': 
        cmd[feature] = pd.Categorical(cmd[feature]).codes
# Out:
# C:\Users\Umashankar\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %%
# To view the dtype info
cmd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1393 entries, 0 to 1472
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Wife_age                   1393 non-null   float64
#  1   Wife_ education            1393 non-null   int8
#  2   Husband_education          1393 non-null   int8
#  3   No_of_children_born        1393 non-null   float64
#  4   Wife_religion              1393 non-null   int8
#  5   Wife_Working               1393 non-null   int8
#  6   Husband_Occupation         1393 non-null   int64
#  7   Standard_of_living_index   1393 non-null   int8
#  8   Media_exposure             1393 non-null   int8
#  9   Contraceptive_method_used  1393 non-null   int8
# dtypes: float64(2), int64(1), int8(7)
# memory usage: 85.3 KB

# %%
# Check the presence of outliers in the entire dataset
plt.figure(figsize=(12,8))
feature_list = cmd.columns
for i in range (len(feature_list)):
    plt.subplot(3, 4, i+1)
    sns.boxplot(y=cmd[feature_list[i]],data=cmd)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %% [markdown]
# ## Insights:
#     * Yes outliners has been detected in all items **These outliers value needs to be treated and there are several ways of treating them:
#     * Drop the outlier value
#     *Replace the outlier value using the IQR

# %%
# Define a function which results the upper and lower limit to detect outliers for each fields
def remove_outlier(col):
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
# Cap & floor the values beyond the outlier boundaries
for i in feature_list:
    LL,UL = remove_outlier(cmd[i])
    cmd[i] = np.where (cmd[i] > UL,UL, cmd[i])
    cmd[i] = np.where (cmd[i] < LL,LL, cmd[i])

# %%
# Check the presence of outliers in the each features
plt.figure(figsize=(12,8))
feature_list = cmd.columns
for i in range (len(feature_list)):
    plt.subplot(3, 4, i+1)
    sns.boxplot(y=cmd[feature_list[i]],data=cmd)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %%
## Checking for Correlations
cmd.corr()
# Out:
#                            Wife_age  Wife_ education  Husband_education  \
# Wife_age                   1.000000        -0.057025          -0.053098
# Wife_ education           -0.057025         1.000000           0.612967
# Husband_education         -0.053098         0.612967           1.000000
# No_of_children_born        0.530123        -0.195769          -0.189733
# Wife_religion                   NaN              NaN                NaN
# Wife_Working               0.032000         0.058523          -0.002612
# Husband_Occupation        -0.187070        -0.370799          -0.324801
# Standard_of_living_index   0.171420         0.341412           0.345690
# Media_exposure                  NaN              NaN                NaN
# Contraceptive_method_used -0.098228         0.228341           0.141775
#
#                            No_of_children_born  Wife_religion  Wife_Working  \
# Wife_age                              0.530123            NaN      0.032000
# ...

# %%
# Check the Heatmap
plt.figure(figsize=(12,8))
sns.heatmap(cmd.iloc[:, 0:10].corr(),annot=True)
plt.show()

# %% [markdown]
# # CART

# %%
# Creating a copy of the original data frame
cmd_1 = cmd.copy()

# %%
# capture the target column ("Contraceptive_method_used") into separate vectors for training set and test set
X = cmd_1.drop("Contraceptive_method_used" , axis=1)
y = cmd_1.pop("Contraceptive_method_used")

# %%
# splitting data into training and test set for independent attributes
X_train, X_test, train_labels, test_labels = train_test_split(X, y, test_size=.30, random_state=1)

# %%
# Import the decisiontreeclassifier library
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(criterion = 'gini' )

# %%
dt_model.fit(X_train, train_labels)
# Out:
# DecisionTreeClassifier()

# %%
# Import the tree library
from sklearn import tree

train_char_label = ['0', '1']
Credit_Tree_File = open('d:\Contraceptive_method.dot','w')
dot_data = tree.export_graphviz(dt_model, out_file=Credit_Tree_File, feature_names = list(X_train), class_names = list(train_char_label))

Credit_Tree_File.close()

# %%
# importance of features in the tree building ( The importance of a feature is computed as the 
#(normalized) total reduction of the criterion brought by that feature. It is also known as the Gini importance )

print (pd.DataFrame(dt_model.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                                Imp
# Wife_age                  0.313660
# Wife_ education           0.118635
# Husband_education         0.053603
# No_of_children_born       0.252898
# Wife_religion             0.000000
# Wife_Working              0.050015
# Husband_Occupation        0.120859
# Standard_of_living_index  0.090331
# Media_exposure            0.000000

# %%
y_predict = dt_model.predict(X_test)

# %% [markdown]
# # Regularising the Decision Tree

# %%
reg_dt_model = DecisionTreeClassifier(criterion = 'gini', max_depth = 7,min_samples_leaf=10,min_samples_split=30)
reg_dt_model.fit(X_train, train_labels)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=10, min_samples_split=30)

# %%
credit_tree_regularized = open('d:\credit_tree_regularized.dot','w')
dot_data = tree.export_graphviz(reg_dt_model, out_file= credit_tree_regularized , feature_names = list(X_train), class_names = list(train_char_label))

credit_tree_regularized.close()

print (pd.DataFrame(dt_model.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                                Imp
# Wife_age                  0.313660
# Wife_ education           0.118635
# Husband_education         0.053603
# No_of_children_born       0.252898
# Wife_religion             0.000000
# Wife_Working              0.050015
# Husband_Occupation        0.120859
# Standard_of_living_index  0.090331
# Media_exposure            0.000000

# %%
ytrain_predict = reg_dt_model.predict(X_train)
ytest_predict = reg_dt_model.predict(X_test)

# %%
import matplotlib.pyplot as plt

# %%
# AUC and ROC for the training data

# predict probabilities
probs = reg_dt_model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(train_labels, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(train_labels, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.824

# %%
# AUC and ROC for the test data
# predict probabilities
probs = reg_dt_model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(test_labels, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(test_labels, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.700

# %%
# Import the classification_report & Confusion_matrix library
from sklearn.metrics import classification_report,confusion_matrix

# %%
# To view the confusion matrix for train_labels, ytrain_predict
confusion_matrix(train_labels, ytrain_predict)
print(classification_report(train_labels, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.62      0.68       422
#          1.0       0.75      0.86      0.80       553
#
#     accuracy                           0.75       975
#    macro avg       0.76      0.74      0.74       975
# weighted avg       0.75      0.75      0.75       975

# %% [markdown]
# # Insight: The confusion matrix and classification report for training data
#     * The precision is having 77% and recall is having 62% for Contraceptive_method_used label is 0
#     * The precision is having 75% and recall is having 86% for Contraceptive_method_used label is 1
#     * The overall accuracy is having 75%

# %%
# To view the confusion matrix for test_labels, ytest_predict
confusion_matrix(test_labels, ytest_predict)
print(classification_report(test_labels, ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.47      0.56       192
#          1.0       0.64      0.81      0.72       226
#
#     accuracy                           0.65       418
#    macro avg       0.66      0.64      0.64       418
# weighted avg       0.66      0.65      0.64       418

# %% [markdown]
# # Insight: The confusion matrix and classification report for Test data
#     * The precision is having 67% and recall is having 47% for Contraceptive_method_used label is 0
#     * The precision is having 64% and recall is having 81% for Contraceptive_method_used label is 1
#     * The overall accuracy is having 65%

# %%
# To view the model score for X_train, train_labels
reg_dt_model.score(X_train,train_labels)
# Out:
# 0.7528205128205128

# %%
# To view the model score for X_test, test_labels
reg_dt_model.score(X_test,test_labels)
# Out:
# 0.65311004784689

# %% [markdown]
# # Logistics Regression

# %%
# Creating a copy of the original data frame
cmd_2 = cmd.copy()

# %%
# Import the LabelEncoder library
from sklearn.preprocessing import LabelEncoder

# %%
# Defining a Label Encoder object instance
LE = LabelEncoder()
LE
# Out:
# LabelEncoder()

# %%
# Applying the created Label Encoder object for the target class
cmd['Contraceptive_method_used'] = LE.fit_transform(cmd['Contraceptive_method_used'])
cmd.head()
# Out:
#    Wife_age  Wife_ education  Husband_education  No_of_children_born  \
# 0      24.0              1.0                2.0                  3.0
# 1      45.0              0.0                2.0                 10.0
# 2      43.0              1.0                2.0                  7.0
# 3      42.0              2.0                1.0                  9.0
# 4      36.0              2.0                2.0                  8.0
#
#    Wife_religion  Wife_Working  Husband_Occupation  Standard_of_living_index  \
# 0            1.0           0.0                 2.0                       2.0
# 1            1.0           0.0                 3.0                       3.0
# 2            1.0           0.0                 3.0                       3.0
# 3            1.0           0.0                 3.0                       2.0
# 4            1.0           0.0                 3.0                       1.0
#
#    Media_exposure   Contraceptive_method_used
# ...

# %%
# Converting the other 'object' type variables as dummy variables
cmd_dummy = pd.get_dummies(cmd_2,drop_first=True)
cmd_dummy.head()
# Out:
#    Wife_age  Wife_ education  Husband_education  No_of_children_born  \
# 0      24.0              1.0                2.0                  3.0
# 1      45.0              0.0                2.0                 10.0
# 2      43.0              1.0                2.0                  7.0
# 3      42.0              2.0                1.0                  9.0
# 4      36.0              2.0                2.0                  8.0
#
#    Wife_religion  Wife_Working  Husband_Occupation  Standard_of_living_index  \
# 0            1.0           0.0                 2.0                       2.0
# 1            1.0           0.0                 3.0                       3.0
# 2            1.0           0.0                 3.0                       3.0
# 3            1.0           0.0                 3.0                       2.0
# 4            1.0           0.0                 3.0                       1.0
#
#    Media_exposure   Contraceptive_method_used
# ...

# %%
# Copy all the predictor variables into X dataframe
X = cmd_dummy.drop('Contraceptive_method_used', axis=1)

# Copy target into the y dataframe. 
y = cmd_dummy['Contraceptive_method_used']

# %%
# Split X and y into training and test set in 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1,
                                                    stratify=cmd_dummy['Contraceptive_method_used'])

# %%
# To view the y_train value count
y_train.value_counts(1)
# Out:
# 1.0    0.558974
# 0.0    0.441026
# Name: Contraceptive_method_used, dtype: float64

# %%
# To view the y_test value count
y_test.value_counts(1)
# Out:
# 1.0    0.559809
# 0.0    0.440191
# Name: Contraceptive_method_used, dtype: float64

# %% [markdown]
# ## Logistic Regression Model

# %%
# Fit the Logistic Regression model
model = LogisticRegression(solver='newton-cg',max_iter=400,penalty='none',verbose=True,n_jobs=2)
model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    2.5s finished
# LogisticRegression(max_iter=400, n_jobs=2, penalty='none', solver='newton-cg',
#                    verbose=True)

# %% [markdown]
# ## Predicting on Training and Test datase

# %%
ytrain_predict = model.predict(X_train)
ytest_predict = model.predict(X_test)

# %% [markdown]
# ## Getting the Predicted Classes and Probability

# %%
ytest_predict_prob=model.predict_proba(X_test)
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.269587  0.730413
# 1  0.626732  0.373268
# 2  0.331280  0.668720
# 3  0.366515  0.633485
# 4  0.305626  0.694374

# %% [markdown]
# ## Model Evaluation

# %%
# Accuracy - Training Data
model.score(X_train, y_train)
# Out:
# 0.6738461538461539

# %% [markdown]
# ## AUC and ROC for the training data

# %%
# predict probabilities
probs = model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.718

# %%
# Accuracy - Test Data
model.score(X_test, y_test)
# Out:
# 0.6483253588516746

# %% [markdown]
# ### AUC and ROC for the test data

# %%
# predict probabilities
probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.718

# %% [markdown]
# ### Confusion Matrix for the training data

# %%
confusion_matrix(y_train, ytrain_predict)
print(classification_report(y_train, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.53      0.59       430
#          1.0       0.68      0.79      0.73       545
#
#     accuracy                           0.67       975
#    macro avg       0.67      0.66      0.66       975
# weighted avg       0.67      0.67      0.67       975

# %%
plot_confusion_matrix(model,X_train,y_train);
# Out:
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Confusion Matrix for test data

# %%
confusion_matrix(y_test, ytest_predict)
print(classification_report(y_test, ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.46      0.54       184
#          1.0       0.65      0.79      0.72       234
#
#     accuracy                           0.65       418
#    macro avg       0.65      0.63      0.63       418
# weighted avg       0.65      0.65      0.64       418

# %%
plot_confusion_matrix(model,X_test,y_test);
# Out:
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Applying GridSearchCV for Logistic Regression

# %%
grid={'penalty':['l2','none'],
      'solver':['sag','lbfgs'],
      'tol':[0.0001,0.00001]}

# %%
model = LogisticRegression(max_iter=400,n_jobs=2)

# %%
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 3,n_jobs=-1,scoring='f1')

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LogisticRegression(max_iter=400, n_jobs=2),
#              n_jobs=-1,
#              param_grid={'penalty': ['l2', 'none'], 'solver': ['sag', 'lbfgs'],
#                          'tol': [0.0001, 1e-05]},
#              scoring='f1')

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)
# Out:
# {'penalty': 'l2', 'solver': 'sag', 'tol': 1e-05}
#
# LogisticRegression(max_iter=400, n_jobs=2, solver='sag', tol=1e-05)

# %%
best_model = grid_search.best_estimator_

# %%
# Prediction on the training set
ytrain_predict = best_model.predict(X_train)
ytest_predict = best_model.predict(X_test)

# %%
## Getting the probabilities on the test set
ytest_predict_prob=best_model.predict_proba(X_test)
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.268408  0.731592
# 1  0.624671  0.375329
# 2  0.331917  0.668083
# 3  0.365570  0.634430
# 4  0.306029  0.693971

# %%
## Confusion matrix on the training data
plot_confusion_matrix(best_model,X_train,y_train)
print(classification_report(y_train, ytrain_predict),'\n');
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.53      0.59       430
#          1.0       0.68      0.79      0.73       545
#
#     accuracy                           0.67       975
#    macro avg       0.67      0.66      0.66       975
# weighted avg       0.67      0.67      0.67       975
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Summary: The confusion matrix and classification report for training data
#     * The precision is having 66% and recall is having 53% for Contraceptive_method_used label is 0
#     * The precision is having 68% and recall is having 79% for Contraceptive_method_used label is 1
#     * The overall accuracy is having 67%

# %%
## Confusion matrix on the test data
plot_confusion_matrix(best_model,X_test,y_test)
print(classification_report(y_test, ytest_predict),'\n');
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.46      0.54       184
#          1.0       0.65      0.79      0.72       234
#
#     accuracy                           0.65       418
#    macro avg       0.65      0.63      0.63       418
# weighted avg       0.65      0.65      0.64       418
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Summary: The confusion matrix and classification report for test data
#     * The precision is having 64% and recall is having 46% for Contraceptive_method_used label is 0
#     * The precision is having 65% and recall is having 79% for Contraceptive_method_used label is 1
#     * The overall accuracy is having 65%

# %%
Specifty= (85/(85+99))

# %%
print(Specifty)
# Out:
# 0.46195652173913043

# %% [markdown]
# # Linear Discriminant Analysis

# %%
# Creating a copy of the original data frame
cmd_3 = cmd.copy()

# %%
# To view the top 5 record using head function of the dataset
cmd_3.head()
# Out:
#    Wife_age  Wife_ education  Husband_education  No_of_children_born  \
# 0      24.0              1.0                2.0                  3.0
# 1      45.0              0.0                2.0                 10.0
# 2      43.0              1.0                2.0                  7.0
# 3      42.0              2.0                1.0                  9.0
# 4      36.0              2.0                2.0                  8.0
#
#    Wife_religion  Wife_Working  Husband_Occupation  Standard_of_living_index  \
# 0            1.0           0.0                 2.0                       2.0
# 1            1.0           0.0                 3.0                       3.0
# 2            1.0           0.0                 3.0                       3.0
# 3            1.0           0.0                 3.0                       2.0
# 4            1.0           0.0                 3.0                       1.0
#
#    Media_exposure   Contraceptive_method_used
# ...

# %%
# capture the target column ("Contraceptive_method_used") into separate vectors for training set and test set
X = cmd_3.drop("Contraceptive_method_used" , axis=1)
y = cmd_3.pop("Contraceptive_method_used")

# %%
# import the model_selection and metrics library file
from sklearn import metrics,model_selection

# %%
# Split X and y into training and test set in 70:30 ratio
X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,test_size=0.30,random_state=1,stratify = y)

# %%
# To check the number of dependent and independent variables in the dataset
print('Number of rows and columns of the training set for the independent variables:',X_train.shape)
print('Number of rows and columns of the training set for the dependent variable:',y_train.shape)
print('Number of rows and columns of the test set for the independent variables:',X_test.shape)
print('Number of rows and columns of the test set for the dependent variable:',y_test.shape)
# Out:
# Number of rows and columns of the training set for the independent variables: (975, 9)
# Number of rows and columns of the training set for the dependent variable: (975,)
# Number of rows and columns of the test set for the independent variables: (418, 9)
# Number of rows and columns of the test set for the dependent variable: (418,)

# %%
# Import the LinearDiscriminantAnalysis library file
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# ### LDA Model

# %%
#Build LDA Model
clf = LinearDiscriminantAnalysis()
model=clf.fit(X_train,y_train)
model
# Out:
# LinearDiscriminantAnalysis()

# %% [markdown]
# ### Generate Coefficients and intercept for the Linear Discriminant Function

# %%
#intercept value
clf.intercept_
# Out:
# array([-0.67133942])

# %%
#coefficients for the Linear Discriminant Function
clf.coef_
# Out:
# array([[-7.10680959e-02,  5.60975886e-01,  6.93257323e-02,
#          3.12163468e-01, -1.09593225e-15, -1.63112756e-01,
#          1.44856377e-01,  3.50587041e-01, -0.00000000e+00]])

# %%
# To view the columns of X_train
X_train.columns
# Out:
# Index(['Wife_age', 'Wife_ education', 'Husband_education',
#        'No_of_children_born', 'Wife_religion', 'Wife_Working',
#        'Husband_Occupation', 'Standard_of_living_index', 'Media_exposure '],
#       dtype='object')

# %% [markdown]
# #### Linear Discriminant Function
# = -0.67133942 + (-7.10680959e-02 x Wife_age) + (5.60975886e-01 x Wife_education) + (6.93257323e-02xHusband_education) +
#          (3.12163468e-01 x No_of_children_born) + (-1.09593225e-15 x Wife_religion) + (-1.63112756e-01 x Wife_Working) +
#          (1.44856377e-01 x Husband_Occupation) + (3.50587041e-01 x Standard_of_living_index) + (-0.00000000e+00 xMedia_exposure)

# %%
# rounded up coefficients 
a=clf.coef_
np.round(a,2)
# Out:
# array([[-0.07,  0.56,  0.07,  0.31, -0.  , -0.16,  0.14,  0.35, -0.  ]])

# %% [markdown]
# #### By the above equation and the coefficients it is clear that
# - predictor ''Wife_ education' has the largest magnitude thus this helps in classifying the best
# - predictor 'Media_exposure ' and 'Wife_religion' has the smallest magnitude thus this helps in classifying the least

# %% [markdown]
# ## Prediction

# %%
# Training Data Class Prediction
pred_class_train = model.predict(X_train)

# Test Data Class Prediction 
pred_class_test = model.predict(X_test)

# %% [markdown]
# ### Training Data and Test Data Confusion Matrix Comparison

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,pred_class_train)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,pred_class_test)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %% [markdown]
# ### Training Data and Test Data Classification Report Comparison

# %%
## Confusion matrix on the training data
plot_confusion_matrix(best_model,X_train,y_train)
print(classification_report(y_train, ytrain_predict),'\n');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.53      0.59       430
#            1       0.68      0.79      0.73       545
#
#     accuracy                           0.67       975
#    macro avg       0.67      0.66      0.66       975
# weighted avg       0.67      0.67      0.67       975
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Summary: The confusion matrix and classification report for training data
#     * The precision is having 66% and recall is having 53% for Contraceptive_method_used label is 0
#     * The precision is having 68% and recall is having 79% for Contraceptive_method_used label is 1
#     * The overall accuracy is having 67%

# %%
## Confusion matrix on the test data
plot_confusion_matrix(best_model,X_test,y_test)
print(classification_report(y_test, ytest_predict),'\n');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.46      0.54       184
#            1       0.65      0.79      0.72       234
#
#     accuracy                           0.65       418
#    macro avg       0.65      0.63      0.63       418
# weighted avg       0.65      0.65      0.64       418
# C:\Users\Umashankar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Summary: The confusion matrix and classification report for test data
#     * The precision is having 64% and recall is having 46% for Contraceptive_method_used label is 0
#     * The precision is having 65% and recall is having 79% for Contraceptive_method_used label is 1
#     * The overall accuracy is having 65%

# %% [markdown]
# ### Probability prediction for the training and test data

# %%
# Training Data Probability Prediction
pred_prob_train = model.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = model.predict_proba(X_test)

# %%
# Prediction of probability for train data
pred_prob_train[:,1]
# Out:
# array([0.34591935, 0.83678151, 0.82233668, 0.63722045, 0.25324015,
#        0.5472908 , 0.53783887, 0.29707031, 0.79504396, 0.72144568,
#        0.63096737, 0.78535308, 0.6116296 , 0.81598319, 0.88650026,
#        0.78746373, 0.77910489, 0.49614551, 0.40762558, 0.73823522,
#        0.677074  , 0.55852648, 0.69976432, 0.16763913, 0.53605746,
#        0.32001288, 0.56541379, 0.39489447, 0.28782373, 0.60541955,
#        0.3533083 , 0.48628979, 0.34115537, 0.70792537, 0.55367951,
#        0.75943097, 0.34454448, 0.52337958, 0.56489238, 0.7349787 ,
#        0.71141003, 0.47619888, 0.18866598, 0.51302518, 0.30566748,
#        0.51083331, 0.75072384, 0.35364   , 0.48580075, 0.7748524 ,
#        0.21155332, 0.57050128, 0.72946107, 0.32460352, 0.49983334,
#        0.6677404 , 0.67840514, 0.37151019, 0.38116655, 0.62881887,
#        0.66679012, 0.6022721 , 0.331391  , 0.58151888, 0.49645938,
#        0.41358133, 0.66979242, 0.24003758, 0.28126758, 0.2977985 ,
# ...

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.717
# AUC for the Test Data: 0.665
